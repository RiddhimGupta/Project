# %% [markdown]
# <a href="https://colab.research.google.com/github/RiddhimGupta/Project/blob/master/Brain_Tumor_Detection_Using_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Data Augmentation**
#
# ## **About the data:**
#
# The dataset contains 2 folders: Yes and No which contains 253 Brain MRI Images. The folder YES contains 155 Brain MRI Images that are tumorous and the folder NO contains 98 Brain MRI Images that are non-tumorous.
#
# Since this is a small dataset, We have used data augmentation in order to create more images.
#
# Also, we could solve the data imbalance issue (since 61% of the data belongs to the tumorous class) using data augmentation.
#
# ## **Import Necessary Modules**

# %%
#Delete a pre uploaded folder
! rm -rf brats
! rm -rf data
! rm -rf logs
! rm -rf models
! rm -rf /root/.kaggle
! rm -rf brats
#brats=folder name

# %%
#Download kaggle data in colab
#https://www.kaggle.com/general/74235
! pip install -q kaggle
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-344a2284-349c-4edc-a88e-74a4a80a5acb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-344a2284-349c-4edc-a88e-74a4a80a5acb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving kaggle.json to kaggle.json

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
# !kaggle datasets download -d navoneel/brain-mri-images-for-brain-tumor-detection
# Out:
# Downloading brain-mri-images-for-brain-tumor-detection.zip to /content
#  40% 6.00M/15.1M [00:00<00:00, 61.3MB/s]
# 100% 15.1M/15.1M [00:00<00:00, 74.1MB/s]

# %%
! unzip brain-mri-images-for-brain-tumor-detection.zip -d brats
! mkdir brats/augmented_data
! mkdir brats/augmented_data/yes
! mkdir brats/augmented_data/no
! rm -rf brats/brain_tumor_dataset
# Out:
# Archive:  brain-mri-images-for-brain-tumor-detection.zip
#   inflating: brats/brain_tumor_dataset/no/1 no.jpeg
#   inflating: brats/brain_tumor_dataset/no/10 no.jpg
#   inflating: brats/brain_tumor_dataset/no/11 no.jpg
#   inflating: brats/brain_tumor_dataset/no/12 no.jpg
#   inflating: brats/brain_tumor_dataset/no/13 no.jpg
#   inflating: brats/brain_tumor_dataset/no/14 no.jpg
#   inflating: brats/brain_tumor_dataset/no/15 no.jpg
#   inflating: brats/brain_tumor_dataset/no/17 no.jpg
#   inflating: brats/brain_tumor_dataset/no/18 no.jpg
#   inflating: brats/brain_tumor_dataset/no/19 no.jpg
#   inflating: brats/brain_tumor_dataset/no/2 no.jpeg
#   inflating: brats/brain_tumor_dataset/no/20 no.jpg
#   inflating: brats/brain_tumor_dataset/no/21 no.jpg
#   inflating: brats/brain_tumor_dataset/no/22 no.jpg
#   inflating: brats/brain_tumor_dataset/no/23 no.jpg
#   inflating: brats/brain_tumor_dataset/no/24 no.jpg
#   inflating: brats/brain_tumor_dataset/no/25 no.jpg
#   inflating: brats/brain_tumor_dataset/no/26 no.jpg
#   inflating: brats/brain_tumor_dataset/no/27 no.jpg
#   inflating: brats/brain_tumor_dataset/no/28 no.jpg
#   inflating: brats/brain_tumor_dataset/no/29 no.jpg
#   inflating: brats/brain_tumor_dataset/no/3 no.jpg
#   inflating: brats/brain_tumor_dataset/no/30 no.jpg
#   inflating: brats/brain_tumor_dataset/no/31 no.jpg
#   inflating: brats/brain_tumor_dataset/no/32 no.jpg
#   inflating: brats/brain_tumor_dataset/no/33 no.jpg
#   inflating: brats/brain_tumor_dataset/no/34 no.jpg
#   inflating: brats/brain_tumor_dataset/no/35 no.jpg
#   inflating: brats/brain_tumor_dataset/no/36 no.jpg
#   inflating: brats/brain_tumor_dataset/no/37 no.jpg
#   inflating: brats/brain_tumor_dataset/no/38 no.jpg
#   inflating: brats/brain_tumor_dataset/no/39 no.jpg
#   inflating: brats/brain_tumor_dataset/no/4 no.jpg
#   inflating: brats/brain_tumor_dataset/no/40 no.jpg
#   inflating: brats/brain_tumor_dataset/no/41 no.jpg
#   inflating: brats/brain_tumor_dataset/no/42 no.jpg
#   inflating: brats/brain_tumor_dataset/no/43 no.jpg
#   inflating: brats/brain_tumor_dataset/no/44no.jpg
#   inflating: brats/brain_tumor_dataset/no/45 no.jpg
#   inflating: brats/brain_tumor_dataset/no/46 no.jpg
#   inflating: brats/brain_tumor_dataset/no/47 no.jpg
#   inflating: brats/brain_tumor_dataset/no/48 no.jpeg
#   inflating: brats/brain_tumor_dataset/no/49 no.jpg
#   inflating: brats/brain_tumor_dataset/no/5 no.jpg
#   inflating: brats/brain_tumor_dataset/no/50 no.jpg
#   inflating: brats/brain_tumor_dataset/no/6 no.jpg
#   inflating: brats/brain_tumor_dataset/no/7 no.jpg
#   inflating: brats/brain_tumor_dataset/no/8 no.jpg
#   inflating: brats/brain_tumor_dataset/no/9 no.jpg
#   inflating: brats/brain_tumor_dataset/no/N1.JPG
#   inflating: brats/brain_tumor_dataset/no/N11.jpg
#   inflating: brats/brain_tumor_dataset/no/N15.jpg
#   inflating: brats/brain_tumor_dataset/no/N16.jpg
#   inflating: brats/brain_tumor_dataset/no/N17.jpg
#   inflating: brats/brain_tumor_dataset/no/N19.JPG
#   inflating: brats/brain_tumor_dataset/no/N2.JPG
#   inflating: brats/brain_tumor_dataset/no/N20.JPG
#   inflating: brats/brain_tumor_dataset/no/N21.jpg
#   inflating: brats/brain_tumor_dataset/no/N22.JPG
#   inflating: brats/brain_tumor_dataset/no/N26.JPG
#   inflating: brats/brain_tumor_dataset/no/N3.jpg
#   inflating: brats/brain_tumor_dataset/no/N5.jpg
#   inflating: brats/brain_tumor_dataset/no/N6.jpg
#   inflating: brats/brain_tumor_dataset/no/No11.jpg
#   inflating: brats/brain_tumor_dataset/no/No12.jpg
#   inflating: brats/brain_tumor_dataset/no/No13.jpg
#   inflating: brats/brain_tumor_dataset/no/No14.jpg
#   inflating: brats/brain_tumor_dataset/no/No15.jpg
#   inflating: brats/brain_tumor_dataset/no/No16.jpg
#   inflating: brats/brain_tumor_dataset/no/No17.jpg
#   inflating: brats/brain_tumor_dataset/no/No18.jpg
#   inflating: brats/brain_tumor_dataset/no/No19.jpg
#   inflating: brats/brain_tumor_dataset/no/No20.jpg
#   inflating: brats/brain_tumor_dataset/no/No21.jpg
#   inflating: brats/brain_tumor_dataset/no/No22.jpg
#   inflating: brats/brain_tumor_dataset/no/no 1.jpg
#   inflating: brats/brain_tumor_dataset/no/no 10.jpg
#   inflating: brats/brain_tumor_dataset/no/no 100.jpg
#   inflating: brats/brain_tumor_dataset/no/no 2.jpg
#   inflating: brats/brain_tumor_dataset/no/no 3.jpg
#   inflating: brats/brain_tumor_dataset/no/no 4.jpg
#   inflating: brats/brain_tumor_dataset/no/no 5.jpeg
#   inflating: brats/brain_tumor_dataset/no/no 6.jpg
#   inflating: brats/brain_tumor_dataset/no/no 7.jpeg
#   inflating: brats/brain_tumor_dataset/no/no 8.jpg
#   inflating: brats/brain_tumor_dataset/no/no 89.jpg
#   inflating: brats/brain_tumor_dataset/no/no 9.png
#   inflating: brats/brain_tumor_dataset/no/no 90.jpg
#   inflating: brats/brain_tumor_dataset/no/no 91.jpeg
#   inflating: brats/brain_tumor_dataset/no/no 92.jpg
#   inflating: brats/brain_tumor_dataset/no/no 923.jpg
#   inflating: brats/brain_tumor_dataset/no/no 94.jpg
#   inflating: brats/brain_tumor_dataset/no/no 95.jpg
#   inflating: brats/brain_tumor_dataset/no/no 96.jpg
#   inflating: brats/brain_tumor_dataset/no/no 97.jpg
#   inflating: brats/brain_tumor_dataset/no/no 98.jpg
#   inflating: brats/brain_tumor_dataset/no/no 99.jpg
#   inflating: brats/brain_tumor_dataset/no/no.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y1.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y10.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y100.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y101.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y102.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y103.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y104.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y105.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y106.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y107.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y108.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y109.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y11.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y111.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y112.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y113.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y114.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y115.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y116.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y117.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y12.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y120.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y13.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y14.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y146.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y147.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y148.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y15.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y153.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y154.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y155.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y156.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y157.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y158.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y159.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y16.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y160.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y161.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y162.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y163.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y164.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y165.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y166.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y167.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y168.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y169.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y17.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y170.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y18.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y180.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y181.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y182.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y183.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y184.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y185.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y186.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y187.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y188.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y19.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y192.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y193.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y194.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y195.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y2.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y20.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y21.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y22.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y23.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y24.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y242.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y243.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y244.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y245.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y246.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y247.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y248.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y249.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y25.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y250.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y251.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y252.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y253.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y254.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y255.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y256.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y257.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y258.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y259.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y26.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y27.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y28.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y29.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y3.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y30.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y31.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y32.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y33.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y34.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y35.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y36.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y37.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y38.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y39.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y4.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y40.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y41.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y42.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y44.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y45.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y46.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y47.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y49.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y50.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y51.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y52.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y53.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y54.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y55.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y56.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y58.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y59.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y6.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y60.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y61.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y62.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y65.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y66.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y67.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y69.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y7.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y70.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y71.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y73.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y74.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y75.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y76.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y77.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y78.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y79.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y8.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y81.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y82.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y85.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y86.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y89.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y9.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y90.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y91.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y92.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y92.png
#   inflating: brats/brain_tumor_dataset/yes/Y95.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y96.jpg
#   inflating: brats/brain_tumor_dataset/yes/Y97.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y98.JPG
#   inflating: brats/brain_tumor_dataset/yes/Y99.JPG
#   inflating: brats/no/1 no.jpeg
#   inflating: brats/no/10 no.jpg
#   inflating: brats/no/11 no.jpg
#   inflating: brats/no/12 no.jpg
#   inflating: brats/no/13 no.jpg
#   inflating: brats/no/14 no.jpg
#   inflating: brats/no/15 no.jpg
#   inflating: brats/no/17 no.jpg
#   inflating: brats/no/18 no.jpg
#   inflating: brats/no/19 no.jpg
#   inflating: brats/no/2 no.jpeg
#   inflating: brats/no/20 no.jpg
#   inflating: brats/no/21 no.jpg
#   inflating: brats/no/22 no.jpg
#   inflating: brats/no/23 no.jpg
#   inflating: brats/no/24 no.jpg
#   inflating: brats/no/25 no.jpg
#   inflating: brats/no/26 no.jpg
#   inflating: brats/no/27 no.jpg
# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m}:{round(s,1)}"

# %%
def augment_data(file_dir, n_generated_samples, save_to_dir):
    """
    Arguments:
        file_dir: A string representing the directory where images that we want to augment are found.
        n_generated_samples: A string representing the number of generated samples using the given image.
        save_to_dir: A string representing the directory in which the generated images will be saved.
    """
    
    #from keras.preprocessing.image import ImageDataGenerator
    #from os import listdir
    
    data_gen = ImageDataGenerator(rotation_range=10, 
                                  width_shift_range=0.1, 
                                  height_shift_range=0.1, 
                                  shear_range=0.1, 
                                  brightness_range=(0.3, 1.0),
                                  horizontal_flip=True, 
                                  vertical_flip=True, 
                                  fill_mode='nearest'
                                 )

    
    for filename in listdir(file_dir):
        # load the image
        image = cv2.imread(file_dir + '/' + filename)
        # reshape the image
        image = image.reshape((1,)+image.shape)
        # prefix of the names for the generated sampels.
        save_prefix = 'aug_' + filename[:-4]
        # generate 'n_generated_samples' sample images
        i=0
        for batch in data_gen.flow(x=image, batch_size=1, save_to_dir=save_to_dir, 
                                           save_prefix=save_prefix, save_format='jpg'):
            i += 1
            if i > n_generated_samples:
                break

# %% [markdown]
# Remember that 61% of the data (155 images) are tumorous. And, 39% of the data (98 images) are non-tumorous.
#
# So, in order to balance the data we can generate 9 new images for every image that belongs to 'NO' class and 6 images for every image that belongs the 'YES' class.

# %%
start_time = time.time()

augmented_data_path = 'brats/augmented_data/'

# augment data for the examples with label equal to 'yes' representing tumurous examples
augment_data(file_dir='brats/yes', n_generated_samples=6, save_to_dir=augmented_data_path+'yes')
# augment data for the examples with label equal to 'no' representing non-tumurous examples
augment_data(file_dir='brats/no', n_generated_samples=9, save_to_dir=augmented_data_path+'no')

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Elapsed time: 0:2:0.4

# %% [markdown]
# Let's see how many tumorous and non-tumorous examples after performing data augmentation:

# %%
def data_summary(main_path):
    
    yes_path = main_path+'yes'
    no_path = main_path+'no'
        
    # number of files (images) that are in the the folder named 'yes' that represent tumorous (positive) examples
    m_pos = len(listdir(yes_path))
    # number of files (images) that are in the the folder named 'no' that represent non-tumorous (negative) examples
    m_neg = len(listdir(no_path))
    # number of all examples
    m = (m_pos+m_neg)
    
    pos_prec = (m_pos* 100.0)/ m
    neg_prec = (m_neg* 100.0)/ m
    
    print(f"Number of examples: {m}")
    print(f"Percentage of positive examples: {pos_prec}%, number of pos examples: {m_pos}") 
    print(f"Percentage of negative examples: {neg_prec}%, number of neg examples: {m_neg}")

# %%
data_summary(augmented_data_path)
# Out:
# Number of examples: 2065
# Percentage of positive examples: 52.54237288135593%, number of pos examples: 1085
# Percentage of negative examples: 47.45762711864407%, number of neg examples: 980

# %% [markdown]
# That's it for this notebook. Now, we can use the augmented data to train our convolutional neural network.

# %% [markdown]
# # **Brain Tumor Detection Using a Convolutional Neural Network**
#
# ## **About the Brain MRI Images dataset:**
#
# The dataset contains 2 folders: YES and NO which contains 253 Brain MRI Images. The folder YES contains 155 Brain MRI Images that are tumorous and the folder NO contains 98 Brain MRI Images that are non-tumorous.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, Input, ZeroPadding2D, BatchNormalization, Activation, MaxPooling2D, Flatten, Dense
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
from sklearn.utils import shuffle
import cv2
import imutils
import numpy as np
import matplotlib.pyplot as plt
import time
from os import listdir

# %matplotlib inline

# %% [markdown]
# ## **Data Preparation & Preprocessing**
#
# In order to crop the part that contains only the brain of the image, We used a cropping technique to find the extreme top, bottom, left and right points of the brain.

# %%
def crop_brain_contour(image, plot=False):
    
    #import imutils
    #import cv2
    #from matplotlib import pyplot as plt
    
    # Convert the image to grayscale, and blur it slightly
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Threshold the image, then perform a series of erosions +
    # dilations to remove any small regions of noise
    thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
    thresh = cv2.erode(thresh, None, iterations=2)
    thresh = cv2.dilate(thresh, None, iterations=2)

    # Find contours in thresholded image, then grab the largest one
    cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    cnts = imutils.grab_contours(cnts)
    c = max(cnts, key=cv2.contourArea)
    

    # Find the extreme points
    extLeft = tuple(c[c[:, :, 0].argmin()][0])
    extRight = tuple(c[c[:, :, 0].argmax()][0])
    extTop = tuple(c[c[:, :, 1].argmin()][0])
    extBot = tuple(c[c[:, :, 1].argmax()][0])
    
    # crop new image out of the original image using the four extreme points (left, right, top, bottom)
    new_image = image[extTop[1]:extBot[1], extLeft[0]:extRight[0]]            

    if plot:
        plt.figure()

        plt.subplot(1, 2, 1)
        plt.imshow(image)
        
        plt.tick_params(axis='both', which='both', 
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)
        
        plt.title('Original Image')
            
        plt.subplot(1, 2, 2)
        plt.imshow(new_image)

        plt.tick_params(axis='both', which='both', 
                        top=False, bottom=False, left=False, right=False,
                        labelbottom=False, labeltop=False, labelleft=False, labelright=False)

        plt.title('Cropped Image')
        
        plt.show()
    
    return new_image

# %% [markdown]
# In order to better understand what it's doing, let's grab an image from the dataset and apply this cropping function to see the result:

# %%
ex_img = cv2.imread('brats/yes/Y1.jpg')
ex_new_img = crop_brain_contour(ex_img, True)

# %% [markdown]
# ## **Load up the data:**
#
# The following function takes two arguments, the first one is a list of directory paths for the folders 'YES' and 'NO' that contain the image data and the second argument is the image size, and for every image in both directories and does the following:
#
# 1. Read the image.
# 2. Crop the part of the image representing only the brain.
# 3. Resize the image (because the images in the dataset come in different sizes (meaning width, height and # of channels). So, we want all of our images to be (240, 240, 3) to feed it as an input to the neural network.
# 4. Apply normalization because we want pixel values to be scaled to the range 0-1.
# 5. Append the image to X and its label to y.
#
# After that, Shuffle X and y, because the data is ordered (meaning the arrays contains the first part belonging to one class and the second part belonging to the other class, and we don't want that).
#
# Finally, Return X and y

# %%
def load_data(dir_list, image_size):
    """
    Read images, resize and normalize them. 
    Arguments:
        dir_list: list of strings representing file directories.
    Returns:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    """

    # load all images in a directory
    X = []
    y = []
    image_width, image_height = image_size
    
    for directory in dir_list:
        for filename in listdir(directory):
            # load the image
            image = cv2.imread(directory + '/' + filename)
            # crop the brain and ignore the unnecessary rest part of the image
            image = crop_brain_contour(image, plot=False)
            # resize image
            image = cv2.resize(image, dsize=(image_width, image_height), interpolation=cv2.INTER_CUBIC)
            # normalize values
            image = image / 255.
            # convert image to numpy array and append it to X
            X.append(image)
            # append a value of 1 to the target array if the image
            # is in the folder named 'yes', otherwise append 0.
            if directory[-3:] == 'yes':
                y.append([1])
            else:
                y.append([0])
                
    X = np.array(X)
    y = np.array(y)
    
    # Shuffle the data
    X, y = shuffle(X, y)
    
    print(f'Number of examples is: {len(X)}')
    print(f'X shape is: {X.shape}')
    print(f'y shape is: {y.shape}')
    
    return X, y

# %% [markdown]
# **Note:** the augmented data directory contains not only the new generated images but also the original images.

# %%
augmented_data_path = 'brats/augmented_data/'
augmented_yes = augmented_data_path+'yes'
augmented_no = augmented_data_path+'no'

IMG_WIDTH, IMG_HEIGHT = (240, 240)

X, y = load_data([augmented_yes, augmented_no], (IMG_WIDTH, IMG_HEIGHT))
# Out:
# Number of examples is: 2065
# X shape is: (2065, 240, 240, 3)
# y shape is: (2065, 1)

# %% [markdown]
# As we see, we have 2065 images. Each images has a shape of (240, 240, 3)=(image_width, image_height, number_of_channels)
#
# ## **Plot sample images:**

# %%
def plot_sample_images(X, y, n=50):
    """
    Plots n sample images for both values of y (labels).
    Arguments:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    """
    
    for label in [0,1]:
        # grab the first n images with the corresponding y values equal to label
        images = X[np.argwhere(y == label)]
        n_images = images[:n]
        
        columns_n = 10
        rows_n = int(n/ columns_n)

        plt.figure(figsize=(20, 10))
        
        i = 1 # current plot        
        for image in n_images:
            plt.subplot(rows_n, columns_n, i)
            plt.imshow(image[0])
            
            # remove ticks
            plt.tick_params(axis='both', which='both', 
                            top=False, bottom=False, left=False, right=False,
                           labelbottom=False, labeltop=False, labelleft=False, labelright=False)
            
            i += 1
        
        label_to_str = lambda label: "Yes" if label == 1 else "No"
        plt.suptitle(f"Brain Tumor: {label_to_str(label)}")
        plt.show()

# %%
plot_sample_images(X, y)

# %% [markdown]
# ## **Split the data:**
# Split X and y into training, validation (development) and validation sets.

# %%
def split_data(X, y, test_size=0.2):
       
    """
    Splits data into training, development and test sets.
    Arguments:
        X: A numpy array with shape = (#_examples, image_width, image_height, #_channels)
        y: A numpy array with shape = (#_examples, 1)
    Returns:
        X_train: A numpy array with shape = (#_train_examples, image_width, image_height, #_channels)
        y_train: A numpy array with shape = (#_train_examples, 1)
        X_val: A numpy array with shape = (#_val_examples, image_width, image_height, #_channels)
        y_val: A numpy array with shape = (#_val_examples, 1)
        X_test: A numpy array with shape = (#_test_examples, image_width, image_height, #_channels)
        y_test: A numpy array with shape = (#_test_examples, 1)
    """
    
    X_train, X_test_val, y_train, y_test_val = train_test_split(X, y, test_size=test_size)
    X_test, X_val, y_test, y_val = train_test_split(X_test_val, y_test_val, test_size=0.5)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

# %% [markdown]
# Let's use the following way to split:
#
# 1. 70% of the data for training.
# 2. 15% of the data for validation.
# 3. 15% of the data for testing.

# %%
X_train, y_train, X_val, y_val, X_test, y_test = split_data(X, y, test_size=0.3)

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of development examples = " + str(X_val.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(y_train.shape))
print ("X_val (dev) shape: " + str(X_val.shape))
print ("Y_val (dev) shape: " + str(y_val.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(y_test.shape))
# Out:
# number of training examples = 1445
# number of development examples = 310
# number of test examples = 310
# X_train shape: (1445, 240, 240, 3)
# Y_train shape: (1445, 1)
# X_val (dev) shape: (310, 240, 240, 3)
# Y_val (dev) shape: (310, 1)
# X_test shape: (310, 240, 240, 3)
# Y_test shape: (310, 1)

# %% [markdown]
# Some helper functions:

# %%
# Nicely formatted time string
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60
    return f"{h}:{m}:{round(s,1)}"

# %%
def compute_f1_score(y_true, prob):
    # convert the vector of probabilities to a target vector
    y_pred = np.where(prob > 0.5, 1, 0)
    
    score = f1_score(y_true, y_pred)
    
    return score

# %% [markdown]
# ## **Build the model**
# Let's build a convolutional neural network model:
#
# ![image.png](data:image/png;base64,...)

# %%
def build_model(input_shape):
    """
    Arugments:
        input_shape: A tuple representing the shape of the input of the model. shape=(image_width, image_height, #_channels)
    Returns:
        model: A Model object.
    """
    # Define the input placeholder as a tensor with shape input_shape. 
    X_input = Input(input_shape) # shape=(?, 240, 240, 3)
    
    # Zero-Padding: pads the border of X_input with zeroes
    X = ZeroPadding2D((2, 2))(X_input) # shape=(?, 244, 244, 3)
    
    # CONV -> BN -> RELU Block applied to X
    X = Conv2D(32, (7, 7), strides = (1, 1), name = 'conv0')(X)
    X = BatchNormalization(axis = 3, name = 'bn0')(X)
    X = Activation('relu')(X) # shape=(?, 238, 238, 32)
    
    # MAXPOOL
    X = MaxPooling2D((4, 4), name='max_pool0')(X) # shape=(?, 59, 59, 32) 
    
    # MAXPOOL
    X = MaxPooling2D((4, 4), name='max_pool1')(X) # shape=(?, 14, 14, 32)
    
    # FLATTEN X 
    X = Flatten()(X) # shape=(?, 6272)
    # FULLYCONNECTED
    X = Dense(1, activation='sigmoid', name='fc')(X) # shape=(?, 1)
    
    # Create model. This creates your Keras model instance, you'll use this instance to train/test the model.
    model = Model(inputs = X_input, outputs = X, name='BrainDetectionModel')
    
    return model

# %% [markdown]
# Define the image shape:

# %%
IMG_SHAPE = (IMG_WIDTH, IMG_HEIGHT, 3)
model = build_model(IMG_SHAPE)
model.summary()
# Out:
# Model: "BrainDetectionModel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 240, 240, 3)]     0
# _________________________________________________________________
# zero_padding2d (ZeroPadding2 (None, 244, 244, 3)       0
# _________________________________________________________________
# conv0 (Conv2D)               (None, 238, 238, 32)      4736
# _________________________________________________________________
# bn0 (BatchNormalization)     (None, 238, 238, 32)      128
# _________________________________________________________________
# activation (Activation)      (None, 238, 238, 32)      0
# _________________________________________________________________
# max_pool0 (MaxPooling2D)     (None, 59, 59, 32)        0
# _________________________________________________________________
# max_pool1 (MaxPooling2D)     (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# fc (Dense)                   (None, 1)                 6273
# =================================================================
# Total params: 11,137
# Trainable params: 11,073
# Non-trainable params: 64
# _________________________________________________________________

# %% [markdown]
# Compile the model:

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
# tensorboard
log_file_name = f'brain_tumor_detection_cnn_{int(time.time())}'
tensorboard = TensorBoard(log_dir=f'logs/{log_file_name}')

# checkpoint
# unique file name that will include the epoch and the validation (development) accuracy
filepath="cnn-parameters-improvement-{epoch:02d}-{val_accuracy:.2f}"
# save the model with the best validation (development) accuracy till now
checkpoint = ModelCheckpoint("models/{}.model".format(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max'))

# %% [markdown]
# Train the model:

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=10, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/10
# 46/46 [==============================] - 127s 3s/step - loss: 0.8205 - accuracy: 0.5936 - val_loss: 0.6536 - val_accuracy: 0.6806
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-01-0.68.model/assets
# Epoch 2/10
# 46/46 [==============================] - 124s 3s/step - loss: 0.4905 - accuracy: 0.7534 - val_loss: 0.6142 - val_accuracy: 0.6129
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-02-0.61.model/assets
# Epoch 3/10
# 46/46 [==============================] - 124s 3s/step - loss: 0.4510 - accuracy: 0.8031 - val_loss: 0.5621 - val_accuracy: 0.7226
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-03-0.72.model/assets
# Epoch 4/10
# 46/46 [==============================] - 123s 3s/step - loss: 0.3522 - accuracy: 0.8405 - val_loss: 0.5332 - val_accuracy: 0.7194
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-04-0.72.model/assets
# Epoch 5/10
# 46/46 [==============================] - 123s 3s/step - loss: 0.2759 - accuracy: 0.8895 - val_loss: 0.7092 - val_accuracy: 0.5548
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-05-0.55.model/assets
# Epoch 6/10
# 46/46 [==============================] - 131s 3s/step - loss: 0.2786 - accuracy: 0.8942 - val_loss: 0.6217 - val_accuracy: 0.6484
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-06-0.65.model/assets
# Epoch 7/10
# 46/46 [==============================] - 123s 3s/step - loss: 0.2669 - accuracy: 0.8920 - val_loss: 0.5200 - val_accuracy: 0.7355
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-07-0.74.model/assets
# Epoch 8/10
# 46/46 [==============================] - 124s 3s/step - loss: 0.2684 - accuracy: 0.8857 - val_loss: 0.3629 - val_accuracy: 0.8355
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-08-0.84.model/assets
# Epoch 9/10
# 46/46 [==============================] - 124s 3s/step - loss: 0.3247 - accuracy: 0.8583 - val_loss: 0.4839 - val_accuracy: 0.7710
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-09-0.77.model/assets
# Epoch 10/10
# 46/46 [==============================] - 124s 3s/step - loss: 0.3485 - accuracy: 0.8548 - val_loss: 0.3319 - val_accuracy: 0.8710
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-10-0.87.model/assets
# Elapsed time: 0:20:59.1

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 46/46 [==============================] - 131s 3s/step - loss: 0.2292 - accuracy: 0.9052 - val_loss: 0.5014 - val_accuracy: 0.7871
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-01-0.79.model/assets
# Epoch 2/3
# 46/46 [==============================] - 125s 3s/step - loss: 0.2319 - accuracy: 0.9010 - val_loss: 0.3423 - val_accuracy: 0.8613
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-02-0.86.model/assets
# Epoch 3/3
# 46/46 [==============================] - 124s 3s/step - loss: 0.1823 - accuracy: 0.9329 - val_loss: 0.2802 - val_accuracy: 0.8968
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-03-0.90.model/assets
# Elapsed time: 0:6:24.3

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 46/46 [==============================] - 124s 3s/step - loss: 0.1482 - accuracy: 0.9460 - val_loss: 0.3047 - val_accuracy: 0.8774
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-01-0.88.model/assets
# Epoch 2/3
# 46/46 [==============================] - 124s 3s/step - loss: 0.1317 - accuracy: 0.9592 - val_loss: 0.5833 - val_accuracy: 0.7774
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-02-0.78.model/assets
# Epoch 3/3
# 46/46 [==============================] - 129s 3s/step - loss: 0.1496 - accuracy: 0.9370 - val_loss: 0.3035 - val_accuracy: 0.8839
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-03-0.88.model/assets
# Elapsed time: 0:6:21.4

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=3, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/3
# 46/46 [==============================] - 125s 3s/step - loss: 0.1243 - accuracy: 0.9599 - val_loss: 0.2890 - val_accuracy: 0.9032
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-01-0.90.model/assets
# Epoch 2/3
# 46/46 [==============================] - 123s 3s/step - loss: 0.1232 - accuracy: 0.9606 - val_loss: 0.2873 - val_accuracy: 0.9065
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-02-0.91.model/assets
# Epoch 3/3
# 46/46 [==============================] - 125s 3s/step - loss: 0.1473 - accuracy: 0.9467 - val_loss: 0.5329 - val_accuracy: 0.7935
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-03-0.79.model/assets
# Elapsed time: 0:6:17.7

# %%
start_time = time.time()

model.fit(x=X_train, y=y_train, batch_size=32, epochs=5, validation_data=(X_val, y_val), callbacks=[tensorboard, checkpoint])

end_time = time.time()
execution_time = (end_time - start_time)
print(f"Elapsed time: {hms_string(execution_time)}")
# Out:
# Epoch 1/5
# 46/46 [==============================] - 124s 3s/step - loss: 0.0957 - accuracy: 0.9696 - val_loss: 0.2831 - val_accuracy: 0.8968
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-01-0.90.model/assets
# Epoch 2/5
# 46/46 [==============================] - 124s 3s/step - loss: 0.0957 - accuracy: 0.9737 - val_loss: 0.2984 - val_accuracy: 0.8968
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-02-0.90.model/assets
# Epoch 3/5
# 46/46 [==============================] - 124s 3s/step - loss: 0.1626 - accuracy: 0.9294 - val_loss: 0.3155 - val_accuracy: 0.8742
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-03-0.87.model/assets
# Epoch 4/5
# 46/46 [==============================] - 124s 3s/step - loss: 0.0921 - accuracy: 0.9654 - val_loss: 0.3824 - val_accuracy: 0.8581
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-04-0.86.model/assets
# Epoch 5/5
# 46/46 [==============================] - 125s 3s/step - loss: 0.0853 - accuracy: 0.9785 - val_loss: 0.4090 - val_accuracy: 0.8548
# INFO:tensorflow:Assets written to: models/cnn-parameters-improvement-05-0.85.model/assets
# Elapsed time: 0:10:28.7

# %%
history = model.history.history

# %%
for key in history.keys():
    print(key)
# Out:
# loss
# accuracy
# val_loss
# val_accuracy

# %% [markdown]
# ## **Plot Loss & Accuracy**

# %%
def plot_metrics(history):
    
    train_loss = history['loss']
    val_loss = history['val_loss']
    train_acc = history['accuracy']
    val_acc = history['val_accuracy']
    
    # Loss
    plt.figure()
    plt.plot(train_loss, label='Training Loss')
    plt.plot(val_loss, label='Validation Loss')
    plt.title('Loss')
    plt.legend()
    plt.show()
    
    # Accuracy
    plt.figure()
    plt.plot(train_acc, label='Training Accuracy')
    plt.plot(val_acc, label='Validation Accuracy')
    plt.title('Accuracy')
    plt.legend()
    plt.show()

# %% [markdown]
# **Note:** Since we trained the model using more than model.fit() function call, this made the history only contain the metric values of the epochs for the last call (which was for 5 epochs), so to plot the metric values across the whole process of trianing the model from the beginning, I had to grab the rest of the values.

# %%
plot_metrics(history)

# %% [markdown]
# ## **Results**
# Let's experiment with the best model (the one with the best validation accuracy):
#
# Concretely, the model at the 18th iteration with validation accuracy of 90.65%
#
# **Load the best model**

# %%
best_model = load_model(filepath='models/cnn-parameters-improvement-05-0.85.model')
best_model.metrics_names
# Out:
# ['loss', 'accuracy']

# %% [markdown]
# Evaluate the best model on the testing data:

# %%
loss, acc = best_model.evaluate(x=X_test, y=y_test)
# Out:
# 10/10 [==============================] - 7s 680ms/step - loss: 0.4287 - accuracy: 0.8355

# %% [markdown]
# **Accuracy of the best model on the testing data:**

# %%
print (f"Test Loss = {loss}")
print (f"Test Accuracy = {acc}")
# Out:
# Test Loss = 0.42872604727745056
# Test Accuracy = 0.8354838490486145

# %% [markdown]
# **F1 score for the best model on the testing data:**

# %%
y_test_prob = best_model.predict(X_test)

f1score = compute_f1_score(y_test, y_test_prob)
print(f"F1 score: {f1score}")
# Out:
# F1 score: 0.8521739130434781

# %% [markdown]
# Let's also find the f1 score on the validation data:

# %%
y_val_prob = best_model.predict(X_val)

f1score_val = compute_f1_score(y_val, y_val_prob)
print(f"F1 score: {f1score_val}")
# Out:
# F1 score: 0.8760330578512396

# %% [markdown]
# **Results Interpretation :**
#
# Let's remember the percentage of positive and negative examples:

# %%
def data_percentage(y):
    
    m=len(y)
    n_positive = np.sum(y)
    n_negative = m - n_positive
    
    pos_prec = (n_positive* 100.0)/ m
    neg_prec = (n_negative* 100.0)/ m
    
    print(f"Number of examples: {m}")
    print(f"Percentage of positive examples: {pos_prec}%, number of pos examples: {n_positive}") 
    print(f"Percentage of negative examples: {neg_prec}%, number of neg examples: {n_negative}")

# %%
# the whole data
data_percentage(y)
# Out:
# Number of examples: 2065
# Percentage of positive examples: 52.54237288135593%, number of pos examples: 1085
# Percentage of negative examples: 47.45762711864407%, number of neg examples: 980

# %%
print("Training Data:")
data_percentage(y_train)
print("Validation Data:")
data_percentage(y_val)
print("Testing Data:")
data_percentage(y_test)
# Out:
# Training Data:
# Number of examples: 1445
# Percentage of positive examples: 52.94117647058823%, number of pos examples: 765
# Percentage of negative examples: 47.05882352941177%, number of neg examples: 680
# Validation Data:
# Number of examples: 310
# Percentage of positive examples: 52.903225806451616%, number of pos examples: 164
# Percentage of negative examples: 47.096774193548384%, number of neg examples: 146
# Testing Data:
# Number of examples: 310
# Percentage of positive examples: 50.32258064516129%, number of pos examples: 156
# Percentage of negative examples: 49.67741935483871%, number of neg examples: 154

# %% [markdown]
# ## **Conclusion:**
# Now, the model detects brain tumor with:
# 83.54% accuracy on the test set.
# 0.85 f1 score on the test set.
# These resutls are very good considering that the data is balanced.
#
# **Performance Table:**
#
#           Validation set	Test set
# Accuracy--------90.6%------83.54%
#
# F1 score--------0.87----------0.85
#
#
#
# Hooray!
